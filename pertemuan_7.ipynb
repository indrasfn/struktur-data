# %% [markdown]
# Binary Tree Secara Manual

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

# Membuat tree secara manual
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# Fungsi inorder traversal
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

print('Hasil inorder traversal dari binary tree:')
inorder(root)
# Out:
# Hasil inorder traversal dari binary tree:
# 4 2 5 1 3

# %% [markdown]
# Binary Search Tree

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

class BinarySearchTree:
  def __init__(self):
    self.root = None

  def insert(self, root, data):
    if root is None:
      return Node(data)
    if data < root.data:
      root.left = self.insert(root.left, data)
    else:
      root.right = self.insert(root.right, data)
    return root

bst = BinarySearchTree()
root = None
data_list = [50, 30, 70, 20, 40, 60, 80]
for value in data_list:
  root = bst.insert(root, value)

# %% [markdown]
# Traversal pada BST

# %%
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

def preorder(node):
  if node:
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

def postorder(node):
  if node:
    postorder(node.left)
    postorder(node.right)
    print(node.data, end=' ')

print('Inorder Traversal:')
inorder(root)
print('\nPreorder Traversal:')
preorder(root)
print('\nPostorder Traversal:')
postorder(root)
# Out:
# Inorder Traversal:
# 20 30 40 50 60 70 80
# Preorder Traversal:
# 50 30 20 40 70 60 80
# Postorder Traversal:
# 20 40 30 60 80 70 50

# %% [markdown]
# Pencarian Nilai dalam BST

# %%
def search(node, key):
  if node is None or node.data == key:
    return node
  if key < node.data:
    return search(node.left, key)
  return search(node.right, key)

# Uji pencarian
key = 60
result = search(root, key)
if result:
  print(f'{key} ditemukan dalam tree.')
else:
  print(f'{key} tidak ditemukan.')

key = 25
result = search(root, key)
if result:
  print(f'{key} ditemukan dalam tree.')
else:
  print(f'{key} tidak ditemukan.')
# Out:
# 60 ditemukan dalam tree.
# 25 tidak ditemukan.

# %% [markdown]
# Tugas 1: Program Struktur Binary Tree Manual

# %%
# Struktur Tree berdasarkan identitas saya
# Nama: Sahrul Indra Safani (jml huruf = 17 & huruf vokal = 7)
# NPM: 2505060042
# Tanggal Lahir: 12 Agustus 2006

class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

# Membuat tree secara manual
root = Node(17)
root.left = Node(7)
root.right = Node(42)
root.left.left = Node(12)
root.right.right = Node(8)

# Fungsi inorder traversal
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

print('Hasil inorder traversal dari identitas saya adalah: ')
inorder(root)
# Out:
# Hasil inorder traversal dari identitas saya adalah:
# 12 7 17 42 8

# %% [markdown]
# Tugas 2: Program Binary Search Tree

# %%
# Tiga digit NPM: 042 = 42
# Tgl, bulan: 12, 8
# ASCII: S = 83, A = 97
# Angka fav: 2, 5
# Semua angkanya: 42, 12, 8, 83, 97, 2, 5

# Definisi Node
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

# Definisi class BinarySearchTree
class BinarySearchTree:
  def __init__(self):
    self.root = None

  def insert(self, root, data):
    if root is None: # jika node kosong
      return Node(data)
    if data < root.data: # jika data lebih kecil
      root.left = self.insert(root.left, data)
    else: # jika data lebih besar
      root.right = self.insert(root.right, data)
    return root

# Membuat object BST
bst = BinarySearchTree()
root = None
data_identitas = [42, 12, 8, 83, 97, 2, 5]
for value in data_identitas:
  root = bst.insert(root, value)

# Inorder Traversal
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

# Preorder Traversal
def preorder(node):
  if node:
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

# Postorder Traversal
def postorder(node):
  if node:
    postorder(node.left)
    postorder(node.right)
    print(node.data, end=' ')

print(f'Data awal: {data_identitas}')
print('\nInorder Traversal: ')
inorder(root)
print('\nPreorder Traversal: ')
preorder(root)
print('\nPostorder Traversal: ')
postorder(root)

# Pencarian Nilai dalam BST
def search(node, key):
  if node is None or node.data == key: # node kosong (tidak ditemukan) atau nilai cocok
    return node
  if key < node.data: # jika target lebih kecil, telusuri subtree kiri
    return search(node.left, key)
  return search(node.right, key) # jika target lebih besar, telusuri subtree kanan

# Uji pencarian
key = 42 # nilai yang dicari
result = search(root, key)
if result:
  print(f'\n\n{key} ditemukan dalam tree.')
else:
  print(f'{key} tidak ditemukan.')

key = 100 # nilai yang dicari
result = search(root, key)
if result:
  print(f'{key} ditemukan dalam tree.')
else:
  print(f'{key} tidak ditemukan.')
# Out:
# Data awal: [42, 12, 8, 83, 97, 2, 5]
#
# Inorder Traversal:
# 2 5 8 12 42 83 97
# Preorder Traversal:
# 42 12 8 2 5 83 97
# Postorder Traversal:
# 5 2 8 12 97 83 42
#
# 42 ditemukan dalam tree.
# 100 tidak ditemukan.
